# %% [markdown]
# Crime Analytics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The kernel failed to start as the Python Environment 'Python 3.14.2' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
